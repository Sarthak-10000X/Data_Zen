# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarthak-10000X/Data_Zen/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import close
import pandas as pd
import numpy as np
import sklearn.preprocessing as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score


# %matplotlib inline

#reading the stock data
data=pd.read_csv("/content/StockData.csv")
print("size of data:", data.shape)
print("COLUMNS:", data.columns)

#selecting required columns
df=data[['open','close','high','low','volume']]
df.head()

#scaling data for good and faster efficiency
minMax=MinMaxScaler()
df_minMaxScaled= pd.DataFrame(minMax.fit_transform(df[['open','close','high','low','volume']]), columns =['open MMS', 'close MMS','high MMS','low MMS','volume MMS'])
df_minMaxScaled.head()

#Splittin data for Training and Testing model
x=df_minMaxScaled.drop(columns='close MMS')
y=df_minMaxScaled['close MMS']

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,)

#Working with model using polynomial feature
poly=PolynomialFeatures(degree=2)
x_poly= poly.fit_transform(x_train)
model=LinearRegression()
model.fit(x_poly, y_train)

#Model Accuracy Matrics
y_pred=model.predict(poly.transform(x_test))

mse=mean_squared_error(y_test, y_pred)
r2=r2_score(y_test, y_pred)

print("Mean-Square-Error:", mse*100)
print("r2_score:", r2*100)

#plotting the graph of result

plt.figure(figsize=(10,6))
plt.plot(y_test,label='Acutal price',linewidth=8)
plt.plot(y_pred,label='Predicted price', linewidth=2)
plt.legend()
plt.show()
# Out:
# size of data: (1258, 14)
# COLUMNS: Index(['symbol', 'date', 'close', 'high', 'low', 'open', 'volume', 'adjClose',
#        'adjHigh', 'adjLow', 'adjOpen', 'adjVolume', 'divCash', 'splitFactor'],
#       dtype='object')
# Mean-Square-Error: 0.0016186408323195939
# r2_score: 99.96140252863754

# %% [markdown]
# # Task
# Perform hyperparameter tuning on the polynomial regression model to find the optimal polynomial degree.

# %% [markdown]
# ## Define a range of degrees
#
# ### Subtask:
# Specify a range of polynomial degrees to test for hyperparameter tuning.

# %% [markdown]
# **Reasoning**:
# Create a list of polynomial degrees to test.

# %%
degrees_to_test = range(1, 6)

# %% [markdown]
# ## Iterate and train
#
# ### Subtask:
# Loop through the defined range of degrees, train the polynomial regression model for each degree.

# %% [markdown]
# **Reasoning**:
# Initialize lists to store metrics and loop through degrees to train and evaluate models.

# %%
mse_scores = []
r2_scores = []

for degree in degrees_to_test:
    poly = PolynomialFeatures(degree=degree)
    x_train_poly = poly.fit_transform(x_train)
    model = LinearRegression()
    model.fit(x_train_poly, y_train)

    x_test_poly = poly.transform(x_test)
    y_pred = model.predict(x_test_poly)

    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    mse_scores.append(mse)
    r2_scores.append(r2)
